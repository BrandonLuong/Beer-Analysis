# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Brandon Luong
# - Noel Molina
# - Margarita Leonova
# - Tatiana Bimatova
# - Huy Le

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# What characteristics of beer (flavors like bitter/sweet/sour/spicy etc.; alcohol percentage; color) influence the rating of beer (Plainly speaking, what kind of beer do people like more)?

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
beer_data_set = pd.read_csv('beer_data_set.csv')
descriptors = pd.ExcelFile('Beer Descriptors Simplified.xlsx')
beer_descriptors = []#pd.read_excel('Beer Descriptors Simplified.xlsx')
for sheet in descriptors.sheet_names:
    df = descriptors.parse(sheet)
    beer_descriptors.append(df)
description_df = pd.concat(beer_descriptors, ignore_index=False, axis=1)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
# remove impact columns from the descriptions dataframe
description_df = description_df.drop(description_df.filter(regex='Impact').columns, axis=1)
# lowercase the column names
description_df.columns = description_df.columns.str.lower()
# rename columns to match the descriptors in both data sets
description_df = description_df.rename(columns = {'fruity':'fruits', 'astringent':'astringency', 'alcoholic':'alcohol'})
description_df

# lowercase the column names
beer_data_set.columns = beer_data_set.columns.str.lower()
# drop 'style key' column and rename 'name' column to 'beer'
beer_data_set = (beer_data_set.drop(columns = ['style key'])
        .rename(columns = {'name': 'beer'})
)
beer_data_set

# checking for missing values
beer_data_set.isna().sum()

# drop rows that contain missing beer entries
beer_data_set = beer_data_set[beer_data_set['beer'].notna()]
beer_data_set
# Out:
#                                              beer  key          style  \
# 0                                           Amber  251        Altbier
# 1                                      Double Bag  252        Altbier
# 2                                  Long Trail Ale  253        Altbier
# 3                                    Doppelsticke  254        Altbier
# 4                                          Scurry  255        Altbier
# ...                                           ...  ...            ...
# 5553                          Red Nose Winter Ale  696  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  697  Winter Warmer
# 5555                         Fish Tale Winterfish  698  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  699  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  700  Winter Warmer
#
#                                       brewery  \
# 0                         Alaskan Brewing Co.
# 1                      Long Trail Brewing Co.
# 2                      Long Trail Brewing Co.
# 3              Uerige Obergärige Hausbrauerei
# 4                           Off Color Brewing
# ...                                       ...
# 5553         Natty Greene's Pub & Brewing Co.
# 5554                   Anchor Brewing Company
# 5555  Fish Brewing Company / Fishbowl Brewpub
# 5556                  Shmaltz Brewing Company
# 5557                     Hoppin' Frog Brewery
#
#                                             description  abv  ave rating  \
# 0     Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1     Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2     Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                                Notes:  8.5        4.15
# 4     Notes:Just cause it's dark and German doesn't ...  5.3        3.67
# ...                                                 ...  ...         ...
# 5553                                             Notes:  6.8        3.59
# 5554  Notes:This is the forty-fifth annual Our Speci...  6.9        3.79
# 5555                                             Notes:  7.5        3.76
# 5556  Notes:Chanukah Beer pours a rich crystal clear...  8.0        3.61
# 5557  Notes:The essence of Christmas is captured in ...  8.6        3.89
#
#       min ibu  max ibu  astringency  body  alcohol  bitter  sweet  sour  \
# 0          25       50           13    32        9      47     74    33
# 1          25       50           12    57       18      33     55    16
# 2          25       50           14    37        6      42     43    11
# 3          25       50           13    55       31      47    101    18
# 4          25       50           21    69       10      63    120    14
# ...       ...      ...          ...   ...      ...     ...    ...   ...
# 5553       35       50            8    44       24      19     52    21
# 5554       35       50           22    73        9      58     87    23
# 5555       35       50           11    36       50      70     72    59
# 5556       35       50            6    64       30      57     78    15
# 5557       35       50            8    50       49      13     71    17
#
#       salty  fruits  hoppy  spices  malty
# 0         0      33     57       8    111
# 1         0      24     35      12     84
# 2         0      10     54       4     62
# 3         1      49     40      16    119
# 4         0      19     36      15    218
# ...     ...     ...    ...     ...    ...
# 5553      0      26     21      96     77
# 5554      0      48     91      44    104
# 5555      0      81    110      18     73
# 5556      1      28     57      23    129
# 5557      0      33     16     148     69
#
# [5556 rows x 20 columns]

# %%
# group the descriptors into three groups: 'flavor and aroma', 'mouthfeel', 'taste'
mouthfeel = ['astringency',	'body',	'alcohol']
taste = ['bitter', 'sweet', 'sour', 'salty']
flavor_and_aroma = ['fruits', 'hoppy', 'spices', 'malty']
beer_data_set['mouthfeel'] = beer_data_set[mouthfeel].sum(axis=1)
beer_data_set['taste'] = beer_data_set[taste].sum(axis=1)
beer_data_set['flavor_and_aroma'] = beer_data_set[flavor_and_aroma].sum(axis=1)
beer_data_set

# aggregated the style of beers into common groups. ex: IPA, Lager, etc.
beer_data_set['style'] = beer_data_set['style'].apply(lambda x: x.split('-')[0])
beer_data_set

# number of beers for each style
beer_data_set['style'].value_counts()

#check for duplicate beers
beer_data_set['beer'].value_counts()

# aggregate the data so that there is only one review for each beer
beer_data_set = beer_data_set.groupby(['style', 'beer']).mean().reset_index()
beer_data_set
# Out:
#               style                                               beer    key  \
# 0           Altbier                                    ALTerior Motive  297.0
# 1           Altbier                                       Ad Astra Ale  264.0
# 2           Altbier                                    Alt-eration Ale  271.0
# 3           Altbier                                            Altbier  262.0
# 4           Altbier                                Alternate Dimension  300.0
# ...             ...                                                ...    ...
# 5346  Winter Warmer                                      Winter Warmer  673.5
# 5347  Winter Warmer  Winter Welcome AleSamuel Smith Old Brewery (Ta...  654.0
# 5348  Winter Warmer                                        Winterbraun  678.0
# 5349  Winter Warmer                                         Winterhook  661.0
# 5350  Winter Warmer                              Young's Winter Warmer  691.0
#
#       abv  ave rating  min ibu  max ibu  astringency  body  alcohol  ...  \
# 0     6.3        4.05     25.0     50.0         27.0  61.0     11.0  ...
# 1     5.6        3.69     25.0     50.0          7.0  30.0      5.0  ...
# 2     5.0        3.81     25.0     50.0         21.0  43.0      3.0  ...
# 3     4.7        4.00     25.0     50.0         34.0  48.0      9.0  ...
# 4     5.6        3.66     25.0     50.0         25.0  50.0     12.0  ...
# ...   ...         ...      ...      ...          ...   ...      ...  ...
# 5346  7.2        3.50     35.0     50.0          7.5  50.5     28.5  ...
# 5347  6.0        3.69     35.0     50.0         17.0  55.0     18.0  ...
# 5348  8.0        3.75     35.0     50.0          4.0  74.0     35.0  ...
# 5349  6.0        3.62     35.0     50.0         11.0  47.0     23.0  ...
# 5350  5.0        3.55     35.0     50.0         10.0  67.0     17.0  ...
#
#       sweet  sour  salty  fruits  hoppy  spices  malty  mouthfeel  taste  \
# 0      61.0  46.0    0.0    40.0   77.0    14.0  110.0       99.0  163.0
# 1      43.0  13.0    1.0    13.0   50.0     6.0   93.0       42.0  100.0
# 2      54.0   7.0    0.0    10.0   60.0     9.0  111.0       67.0  115.0
# 3      59.0  25.0    1.0    32.0   68.0    12.0  121.0       91.0  140.0
# 4      61.0  20.0    0.0    21.0   59.0    26.0  139.0       87.0  153.0
# ...     ...   ...    ...     ...    ...     ...    ...        ...    ...
# 5346   58.0  15.5    0.5    25.0   25.5    79.0   85.0       86.5  110.5
# 5347   65.0  22.0    1.0    30.0   69.0    30.0   95.0       90.0  137.0
# 5348   77.0  17.0    2.0    29.0   37.0    27.0  126.0      113.0  148.0
# 5349   51.0  15.0    0.0    15.0   93.0    40.0   97.0       81.0  133.0
# 5350   73.0  19.0    0.0    19.0   32.0    43.0  100.0       94.0  120.0
#
#       flavor_and_aroma
# 0                241.0
# 1                162.0
# 2                190.0
# 3                233.0
# 4                245.0
# ...                ...
# 5346             214.5
# 5347             224.0
# 5348             219.0
# 5349             245.0
# 5350             194.0
#
# [5351 rows x 21 columns]

# %%
# check if the values in the descriptors aren't greater than the amount of descriptive words
check_desc = beer_data_set.set_index('beer').iloc[:, 5:].reset_index()
for desc in description_df.columns:
    check_desc[desc] = description_df[desc].dropna().count() - check_desc[desc]

# we can see that there are some negative values in the descriptor fields. This implies that the same word was used more than once to describe the beer.
check_desc

# the number of impact words for each beer feature
num_desc_words = np.invert(description_df.isna()).sum()


mouthfeel = ['astringency',	'body',	'alcohol']
taste = ['bitter', 'sweet', 'sour', 'salty']
flavor_and_aroma = ['fruits', 'hoppy', 'spices', 'malty']
# the number of descriptors for each group
num_mouthfeel = np.invert(description_df[mouthfeel].isna()).sum().sum()
num_taste = np.invert(description_df[taste].isna()).sum().sum()
num_flavor = np.invert(description_df[flavor_and_aroma].isna()).sum().sum()

# %%
# standardize the descriptors and descriptor groups
beer_data_set['astringency'] = beer_data_set['astringency'].apply(lambda x: x  / num_desc_words.loc['astringency'])

beer_data_set['body'] = beer_data_set['body'].apply(lambda x: x  / num_desc_words.loc['body'])

beer_data_set['alcohol'] = beer_data_set['alcohol'].apply(lambda x: x  / num_desc_words.loc['alcohol'])

beer_data_set['bitter'] = beer_data_set['bitter'].apply(lambda x: x  / num_desc_words.loc['bitter'])

beer_data_set['sweet'] = beer_data_set['sweet'].apply(lambda x: x  / num_desc_words.loc['sweet'])

beer_data_set['sour'] = beer_data_set['sour'].apply(lambda x: x  / num_desc_words.loc['sour'])

beer_data_set['salty'] = beer_data_set['salty'].apply(lambda x: x  / num_desc_words.loc['salty'])

beer_data_set['fruits'] = beer_data_set['fruits'].apply(lambda x: x  / num_desc_words.loc['fruits'])

beer_data_set['hoppy'] = beer_data_set['hoppy'].apply(lambda x: x  / num_desc_words.loc['hoppy'])

beer_data_set['spices'] = beer_data_set['spices'].apply(lambda x: x  / num_desc_words.loc['spices'])

beer_data_set['malty'] = beer_data_set['malty'].apply(lambda x: x  / num_desc_words.loc['malty'])

beer_data_set['mouthfeel'] = beer_data_set['mouthfeel'].apply(lambda x: x  / num_mouthfeel)

beer_data_set['taste'] = beer_data_set['taste'].apply(lambda x: x  / num_taste)

beer_data_set['flavor_and_aroma'] = beer_data_set['flavor_and_aroma'].apply(lambda x: x  / num_taste)

# %%
# final clean data set
final = beer_data_set
final
# Out:
#               style                                               beer    key  \
# 0           Altbier                                    ALTerior Motive  297.0
# 1           Altbier                                       Ad Astra Ale  264.0
# 2           Altbier                                    Alt-eration Ale  271.0
# 3           Altbier                                            Altbier  262.0
# 4           Altbier                                Alternate Dimension  300.0
# ...             ...                                                ...    ...
# 5346  Winter Warmer                                      Winter Warmer  673.5
# 5347  Winter Warmer  Winter Welcome AleSamuel Smith Old Brewery (Ta...  654.0
# 5348  Winter Warmer                                        Winterbraun  678.0
# 5349  Winter Warmer                                         Winterhook  661.0
# 5350  Winter Warmer                              Young's Winter Warmer  691.0
#
#       abv  ave rating  min ibu  max ibu  astringency      body   alcohol  ...  \
# 0     6.3        4.05     25.0     50.0     0.303371  0.628866  0.171875  ...
# 1     5.6        3.69     25.0     50.0     0.078652  0.309278  0.078125  ...
# 2     5.0        3.81     25.0     50.0     0.235955  0.443299  0.046875  ...
# 3     4.7        4.00     25.0     50.0     0.382022  0.494845  0.140625  ...
# 4     5.6        3.66     25.0     50.0     0.280899  0.515464  0.187500  ...
# ...   ...         ...      ...      ...          ...       ...       ...  ...
# 5346  7.2        3.50     35.0     50.0     0.084270  0.520619  0.445312  ...
# 5347  6.0        3.69     35.0     50.0     0.191011  0.567010  0.281250  ...
# 5348  8.0        3.75     35.0     50.0     0.044944  0.762887  0.546875  ...
# 5349  6.0        3.62     35.0     50.0     0.123596  0.484536  0.359375  ...
# 5350  5.0        3.55     35.0     50.0     0.112360  0.690722  0.265625  ...
#
#          sweet      sour     salty    fruits     hoppy    spices     malty  \
# 0     0.476562  0.414414  0.000000  0.229885  0.520270  0.141414  0.526316
# 1     0.335938  0.117117  0.076923  0.074713  0.337838  0.060606  0.444976
# 2     0.421875  0.063063  0.000000  0.057471  0.405405  0.090909  0.531100
# 3     0.460938  0.225225  0.076923  0.183908  0.459459  0.121212  0.578947
# 4     0.476562  0.180180  0.000000  0.120690  0.398649  0.262626  0.665072
# ...        ...       ...       ...       ...       ...       ...       ...
# 5346  0.453125  0.139640  0.038462  0.143678  0.172297  0.797980  0.406699
# 5347  0.507812  0.198198  0.076923  0.172414  0.466216  0.303030  0.454545
# 5348  0.601562  0.153153  0.153846  0.166667  0.250000  0.272727  0.602871
# 5349  0.398438  0.135135  0.000000  0.086207  0.628378  0.404040  0.464115
# 5350  0.570312  0.171171  0.000000  0.109195  0.216216  0.434343  0.478469
#
#       mouthfeel     taste  flavor_and_aroma
# 0         0.396  0.482249          0.713018
# 1         0.168  0.295858          0.479290
# 2         0.268  0.340237          0.562130
# 3         0.364  0.414201          0.689349
# 4         0.348  0.452663          0.724852
# ...         ...       ...               ...
# 5346      0.346  0.326923          0.634615
# 5347      0.360  0.405325          0.662722
# 5348      0.452  0.437870          0.647929
# 5349      0.324  0.393491          0.724852
# 5350      0.376  0.355030          0.573964
#
# [5351 rows x 21 columns]

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %%
# set figure size
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.scatterplot(data = final, x = 'ave rating', y = 'abv').set(title='Alcohol Percentage (ABV) vs. Average Rating')
# Out:
# [Text(0.5, 1.0, 'Alcohol Percentage (ABV) vs. Average Rating')]

# %% [markdown]
# We can see that there are a few outliers with a very high alcohol percentage that we probably don't wanna include as it doesn't really make sense to consider those drinks as beers. We'll get rid of the two that have ABV > 25%.
# We can also see a cluster of beers at the bottom of the graph with a really low ABV, so it makes sense to differentiate between the two gropus. We made a new column "is alcoholic" to differentiate alcoholic vs non/low alcoholic beers based on 2.5% ABV. This is the threshold according to federal law[^fedLaw]
#
#
# [^fedLaw]: https://www.ttb.gov/images/pdfs/beer-bam/chapter1.pdf

# %%
new_final = final[final['abv'] <= 25] # took 3 beers that were above 25% alcohol
new_final['Is Alcoholic'] = (new_final['abv'] > 2.5) # created new column to distinguish alcoholic beers vs. non/low alcoholic beers (> 2.5 abv)
# Out:
# C:\Users\nmoli\AppData\Local\Temp\ipykernel_11800\1981287028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_final['Is Alcoholic'] = (new_final['abv'] > 2.5) # created new column to distinguish alcoholic beers vs. non/low alcoholic beers (> 2.5 abv)

# %%
final_grouped = new_final.groupby('style').mean().reset_index().sort_values('abv')
sns.set(rc = {'figure.figsize':(17,12)})
g = sns.barplot(data = final_grouped, x = 'abv', y = 'style')
g.set_xticks(range(12))
g.set(title='Styles by Alcohol Percentage')
# Out:
# [Text(0.5, 1.0, 'Styles by Alcohol Percentage')]

# %% [markdown]
# We first grouped beers by style and aggragated to find the mean of the ABV (alcohol by volume). We sorted the means of each style in increasing order and graphed the data as shown above. There is a significant difference in the 2 lowest ABV beers and 2 highest ABV beers. The styles Low Alcohol Beer and Kvass have ABV's of around 0.5 and 1.8 respectively, with the next highest beer having an ABV of around 4.2. Similarly, the top two beers by ABV have about 1 ABV unit higher than the next lowest beer by ABV.

# %%
final_grouped2 = new_final.groupby('style').mean().reset_index().sort_values('ave rating')
sns.set(rc = {'figure.figsize':(17,12)})
g = sns.barplot(data = final_grouped2, x = 'ave rating', y = 'style')
g.set_xticks(range(5))
g.set(title='Styles by Average Rating')
# Out:
# [Text(0.5, 1.0, 'Styles by Average Rating')]

# %% [markdown]
# We then looked at the average ratings of all of the beer styles. There appears to be no significant difference in average ratings when we look at the vast majority of the styles. It is interesting to note many of the beer styles appear to be in the same order as the previous bar graph. This implies there may be a correlation between ABV and average ratings for the different beer styles.

# %%
sns.set(rc = {'figure.figsize':(15,15)})
ax = sns.scatterplot(data = final_grouped, x = 'abv', y = 'ave rating', hue = 'style')
ax.set(title='Average Rating vs. Alcohol Percentage (ABV)')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# Here's a scatterplot between ABV and Avg Rating to get a better idea of their relationship after looking after the barplots above.
# There's clearly a positive trend between ABV and Avg Rating.

# %%
fig1 = sns.pairplot(data = new_final[['style', 'abv', 'ave rating', 'min ibu', 'max ibu', 'astringency', 'Is Alcoholic']], hue = 'Is Alcoholic')
fig1.fig.suptitle('Pairwise Relationships Between Style, Alcohol Percentage (ABV), Average Rating, Bitterness', y=1.05)
# Out:
# Text(0.5, 1.05, 'Pairwise Relationships Between Style, Alcohol Percentage (ABV), Average Rating, Bitterness')

# %% [markdown]
# The distributions for ABV, Avg rating and astringency seem to have a skewed distribution. Both IBU's have a non-normal distribution.
# If we look at the IBU's against Avg rating, we can see that the data is clustered because IBU is incremented by 5's in our data set.
# Astringency and Avg rating appears to have a positive correlation.
# The other parts of the graph are irrelevant for our purposes.

# %%
fig2 = sns.pairplot(data = new_final[['ave rating', 'fruits', 'hoppy', 'spices', 'malty', 'Is Alcoholic']], hue = 'Is Alcoholic')
fig2.fig.suptitle('Pairwise Relationships Between Average Rating, Fruits, Hoppy, Spices, Malty', y=1.05)
fig3 = sns.pairplot(data = new_final[['ave rating', 'bitter', 'sweet', 'sour', 'salty', 'Is Alcoholic']], hue = 'Is Alcoholic')
fig3.fig.suptitle('Pairwise Relationships Between Average Rating, Bitterness, Sweetness, Sourness, Saltiness', y=1.05)
# Out:
# Text(0.5, 1.05, 'Pairwise Relationships Between Average Rating, Bitterness, Sweetness, Sourness, Saltiness')

# %% [markdown]
# Here we explored the distributions of variables representing the taste characteristics.
# Distributions:
# - Avg rating looks like a normal distribution
# - fruits, hoppy, spices, malty, bitter, sweet, sour, salty all appear to be right skewed. Which makes sense becacuse too much of particular flavor characteristic (for example, if the beer is too sour) can get overwhelming and not pleasant to drink.
#
# We also looked at the relationship between them and Avg rating. To establish the relationship we look at the Avg rating column.
# For most of the characteristics, we observed: if the characteristic is low, then the average rating is also low. Conversely, the higher the rating gets, the higher the variability of the characteristic for the beer. For example: if the beer has a high rating, the beer can have a low, medium, or high sweetness score; but if the beer has a low rating, the beer is very much more likely to have a low sweetness score.

# %%
new_final = new_final.rename(columns = {'ave rating': 'avg_rating'})
new_final
# Out:
#               style                                               beer    key  \
# 0           Altbier                                    ALTerior Motive  297.0
# 1           Altbier                                       Ad Astra Ale  264.0
# 2           Altbier                                    Alt-eration Ale  271.0
# 3           Altbier                                            Altbier  262.0
# 4           Altbier                                Alternate Dimension  300.0
# ...             ...                                                ...    ...
# 5346  Winter Warmer                                      Winter Warmer  673.5
# 5347  Winter Warmer  Winter Welcome AleSamuel Smith Old Brewery (Ta...  654.0
# 5348  Winter Warmer                                        Winterbraun  678.0
# 5349  Winter Warmer                                         Winterhook  661.0
# 5350  Winter Warmer                              Young's Winter Warmer  691.0
#
#       abv  avg_rating  min ibu  max ibu  astringency      body   alcohol  ...  \
# 0     6.3        4.05     25.0     50.0     0.303371  0.628866  0.171875  ...
# 1     5.6        3.69     25.0     50.0     0.078652  0.309278  0.078125  ...
# 2     5.0        3.81     25.0     50.0     0.235955  0.443299  0.046875  ...
# 3     4.7        4.00     25.0     50.0     0.382022  0.494845  0.140625  ...
# 4     5.6        3.66     25.0     50.0     0.280899  0.515464  0.187500  ...
# ...   ...         ...      ...      ...          ...       ...       ...  ...
# 5346  7.2        3.50     35.0     50.0     0.084270  0.520619  0.445312  ...
# 5347  6.0        3.69     35.0     50.0     0.191011  0.567010  0.281250  ...
# 5348  8.0        3.75     35.0     50.0     0.044944  0.762887  0.546875  ...
# 5349  6.0        3.62     35.0     50.0     0.123596  0.484536  0.359375  ...
# 5350  5.0        3.55     35.0     50.0     0.112360  0.690722  0.265625  ...
#
#           sour     salty    fruits     hoppy    spices     malty  mouthfeel  \
# 0     0.414414  0.000000  0.229885  0.520270  0.141414  0.526316      0.396
# 1     0.117117  0.076923  0.074713  0.337838  0.060606  0.444976      0.168
# 2     0.063063  0.000000  0.057471  0.405405  0.090909  0.531100      0.268
# 3     0.225225  0.076923  0.183908  0.459459  0.121212  0.578947      0.364
# 4     0.180180  0.000000  0.120690  0.398649  0.262626  0.665072      0.348
# ...        ...       ...       ...       ...       ...       ...        ...
# 5346  0.139640  0.038462  0.143678  0.172297  0.797980  0.406699      0.346
# 5347  0.198198  0.076923  0.172414  0.466216  0.303030  0.454545      0.360
# 5348  0.153153  0.153846  0.166667  0.250000  0.272727  0.602871      0.452
# 5349  0.135135  0.000000  0.086207  0.628378  0.404040  0.464115      0.324
# 5350  0.171171  0.000000  0.109195  0.216216  0.434343  0.478469      0.376
#
#          taste  flavor_and_aroma  Is Alcoholic
# 0     0.482249          0.713018          True
# 1     0.295858          0.479290          True
# 2     0.340237          0.562130          True
# 3     0.414201          0.689349          True
# 4     0.452663          0.724852          True
# ...        ...               ...           ...
# 5346  0.326923          0.634615          True
# 5347  0.405325          0.662722          True
# 5348  0.437870          0.647929          True
# 5349  0.393491          0.724852          True
# 5350  0.355030          0.573964          True
#
# [5348 rows x 22 columns]

# %%
# does alcohol by volume percentage affect a beer's average rating?

import patsy
import statsmodels.api as sm
import scipy.stats as stats

outcome_avg_rating, predictor = patsy.dmatrices('avg_rating ~ abv', new_final)
mod1 = sm.OLS(outcome_avg_rating, predictor)
res1 = mod1.fit()
print(res1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             avg_rating   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     1209.
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):          4.49e-239
# Time:                        14:11:10   Log-Likelihood:                -2748.8
# No. Observations:                5348   AIC:                             5502.
# Df Residuals:                    5346   BIC:                             5515.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2285      0.016    199.193      0.000       3.197       3.260
# abv            0.0798      0.002     34.777      0.000       0.075       0.084
# ==============================================================================
# Omnibus:                     1736.200   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7309.802
# Skew:                          -1.544   Prob(JB):                         0.00
# Kurtosis:                       7.824   Cond. No.                         21.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Does the taste of a beer affect a beer's average rating?

outcome_avg_rating1, predictor1 = patsy.dmatrices('avg_rating ~ taste', new_final)
mod2 = sm.OLS(outcome_avg_rating1, predictor1)
res2 = mod2.fit()
print(res2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             avg_rating   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     1056.
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):          1.35e-211
# Time:                        14:15:11   Log-Likelihood:                -2812.0
# No. Observations:                5348   AIC:                             5628.
# Df Residuals:                    5346   BIC:                             5641.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4305      0.012    297.349      0.000       3.408       3.453
# taste          0.8929      0.027     32.499      0.000       0.839       0.947
# ==============================================================================
# Omnibus:                     1097.014   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2945.800
# Skew:                          -1.097   Prob(JB):                         0.00
# Kurtosis:                       5.900   Cond. No.                         5.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Does a salty beer flavor affect a beer's rating?

outcome_avg_rating2, predictor2 = patsy.dmatrices('avg_rating ~ salty', new_final)
mod3 = sm.OLS(outcome_avg_rating2, predictor2)
res3 = mod3.fit()
print(res3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             avg_rating   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1825
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):              0.669
# Time:                        14:23:15   Log-Likelihood:                -3294.1
# No. Observations:                5348   AIC:                             6592.
# Df Residuals:                    5346   BIC:                             6605.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7575      0.006    580.338      0.000       3.745       3.770
# salty          0.0089      0.021      0.427      0.669      -0.032       0.049
# ==============================================================================
# Omnibus:                     1353.701   Durbin-Watson:                   1.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3947.406
# Skew:                          -1.314   Prob(JB):                         0.00
# Kurtosis:                       6.288   Cond. No.                         3.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Does a beer's mouthfeel affect a beer's average rating?

outcome_avg_rating3, predictor3 = patsy.dmatrices('avg_rating ~ mouthfeel', new_final)
mod4 = sm.OLS(outcome_avg_rating3, predictor3)
res4 = mod4.fit()
print(res4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             avg_rating   R-squared:                       0.120
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     725.7
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):          5.51e-150
# Time:                        14:24:47   Log-Likelihood:                -2953.8
# No. Observations:                5348   AIC:                             5912.
# Df Residuals:                    5346   BIC:                             5925.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4738      0.012    288.865      0.000       3.450       3.497
# mouthfeel      0.9528      0.035     26.938      0.000       0.883       1.022
# ==============================================================================
# Omnibus:                     1305.096   Durbin-Watson:                   1.207
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4082.963
# Skew:                          -1.239   Prob(JB):                         0.00
# Kurtosis:                       6.490   Cond. No.                         6.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Does a beer's spices affect a beer's average rating?

outcome_avg_rating4, predictor4 = patsy.dmatrices('avg_rating ~ spices', new_final)
mod5 = sm.OLS(outcome_avg_rating4, predictor4)
res5 = mod5.fit()
print(res5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             avg_rating   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     150.4
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           3.97e-34
# Time:                        14:26:46   Log-Likelihood:                -3219.9
# No. Observations:                5348   AIC:                             6444.
# Df Residuals:                    5346   BIC:                             6457.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7039      0.008    493.811      0.000       3.689       3.719
# spices         0.3081      0.025     12.266      0.000       0.259       0.357
# ==============================================================================
# Omnibus:                     1254.033   Durbin-Watson:                   1.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3515.964
# Skew:                          -1.232   Prob(JB):                         0.00
# Kurtosis:                       6.116   Cond. No.                         4.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# We will try to evaluate if ABV predicts these other variables as well (taste, mouthfeel, etc). If so, these other variables are not independent
# because they are dependent on ABV. Therefore, they are not needed, as average rating is dependent on ABV as well.

outcome_taste, predictor_abv = patsy.dmatrices('taste ~ abv', new_final)
mod9000 = sm.OLS(outcome_taste, predictor_abv)
res9000 = mod9000.fit()
print(res9000.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  taste   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     415.9
# Date:                Wed, 30 Nov 2022   Prob (F-statistic):           4.36e-89
# Time:                        14:37:02   Log-Likelihood:                 1118.6
# No. Observations:                5348   AIC:                            -2233.
# Df Residuals:                    5346   BIC:                            -2220.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2164      0.008     27.518      0.000       0.201       0.232
# abv            0.0227      0.001     20.393      0.000       0.021       0.025
# ==============================================================================
# Omnibus:                      104.215   Durbin-Watson:                   1.286
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              130.419
# Skew:                           0.266   Prob(JB):                     4.79e-29
# Kurtosis:                       3.549   Cond. No.                         21.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# From the results above, we see that ABV affects a beer's taste as well. Therefore, a beer's taste does no affect it's average rating but a beer's abv
# affects it's average rating and taste.
